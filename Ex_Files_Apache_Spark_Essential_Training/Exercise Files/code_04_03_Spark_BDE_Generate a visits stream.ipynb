# %% [markdown]
# ### Create a stream of website visits records

# %%
from kafka import KafkaProducer
import datetime
import random
import json
import time

visits_topic="spark.streaming.website.visits"

def string_serializer(value):
    return value.encode('utf-8')
    
visits_producer=KafkaProducer( 
                bootstrap_servers=["localhost:9092"],
                key_serializer=string_serializer,
                value_serializer=string_serializer
                )

countries = ["USA","India","Brazil","Australia","Russia"]
last_actions = ["Catalog","FAQ","Order","ShoppingCart"]

#Generate 100 sample visit records
for i in range(1,100):

    #Create a json string with generated data
    json_record={}
    json_record["country"]=countries[random.randint(0,4)]
    json_record["last_action"]=last_actions[random.randint(0,3)]
    json_record["visit_date"]=datetime.datetime.today().strftime("%Y-%m-%d %H:%M:%S")
    json_record["duration"]=random.randint(1,20)

    #Use country as Key. Each country will go through the same partition, 
    #hence updates to a given country can be handled sequencially
    kafka_key=json_record["country"]
    kafka_value = json.dumps(json_record)
    print(kafka_value)
    visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)

    #sleep for 1-3 seconds
    time.sleep(random.randint(1,3))

visits_producer.flush()
visits_producer.close()
# Out:
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:05:16", "duration": 17}
# {"country": "India", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:19", "duration": 19}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-03-28 12:05:21", "duration": 5}
# {"country": "India", "last_action": "Order", "visit_date": "2025-03-28 12:05:24", "duration": 15}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-03-28 12:05:26", "duration": 20}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:29", "duration": 1}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:05:31", "duration": 19}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2025-03-28 12:05:32", "duration": 13}
# {"country": "India", "last_action": "Order", "visit_date": "2025-03-28 12:05:33", "duration": 9}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:05:34", "duration": 16}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-03-28 12:05:37", "duration": 2}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-03-28 12:05:38", "duration": 4}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-03-28 12:05:41", "duration": 7}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:42", "duration": 9}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:44", "duration": 5}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:46", "duration": 12}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:48", "duration": 20}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-03-28 12:05:49", "duration": 1}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-03-28 12:05:52", "duration": 15}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:05:53", "duration": 10}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-03-28 12:05:56", "duration": 12}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-03-28 12:05:58", "duration": 18}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-03-28 12:05:59", "duration": 8}
# {"country": "India", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:00", "duration": 20}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-03-28 12:06:01", "duration": 2}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:04", "duration": 7}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-03-28 12:06:06", "duration": 3}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:09", "duration": 4}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:11", "duration": 14}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-03-28 12:06:13", "duration": 18}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:15", "duration": 4}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-03-28 12:06:16", "duration": 16}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-03-28 12:06:18", "duration": 2}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:20", "duration": 3}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-03-28 12:06:21", "duration": 16}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:24", "duration": 4}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:26", "duration": 8}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:28", "duration": 12}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:30", "duration": 19}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-03-28 12:06:33", "duration": 13}
# {"country": "Russia", "last_action": "Order", "visit_date": "2025-03-28 12:06:36", "duration": 1}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:38", "duration": 6}
# {"country": "USA", "last_action": "Order", "visit_date": "2025-03-28 12:06:41", "duration": 11}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2025-03-28 12:06:42", "duration": 12}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-03-28 12:06:44", "duration": 3}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:47", "duration": 19}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:48", "duration": 1}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:50", "duration": 10}
# {"country": "India", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:52", "duration": 9}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:54", "duration": 1}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:06:57", "duration": 18}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-03-28 12:06:58", "duration": 2}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:07:01", "duration": 19}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-03-28 12:07:02", "duration": 6}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-03-28 12:07:04", "duration": 4}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-03-28 12:07:05", "duration": 16}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2025-03-28 12:07:06", "duration": 8}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-03-28 12:07:08", "duration": 10}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2025-03-28 12:07:10", "duration": 13}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2025-03-28 12:07:13", "duration": 9}
# {"country": "Australia", "last_action": "Order", "visit_date": "2025-03-28 12:07:15", "duration": 18}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-03-28 12:07:17", "duration": 13}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-03-28 12:07:19", "duration": 15}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2025-03-28 12:07:22", "duration": 6}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-03-28 12:07:25", "duration": 20}
# {"country": "India", "last_action": "FAQ", "visit_date": "2025-03-28 12:07:28", "duration": 20}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 39
#      36     visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)
#      38     #sleep for 1-3 seconds
# ---> 39     time.sleep(random.randint(1,3))
#      41 visits_producer.flush()
#      42 visits_producer.close()
#
# KeyboardInterrupt:

# %%
#Consumer test - to test if topic data is published correctly
from kafka import KafkaConsumer

def string_deserializer(value):
    return value.decode('utf-8')
    
visits_consumer=KafkaConsumer(
                bootstrap_servers=["localhost:9092"],
                value_deserializer=string_deserializer,
                auto_offset_reset="latest"
                )

visits_consumer.subscribe(visits_topic)

messages = visits_consumer.poll()
print("Total messages :", len(messages))
for message in messages:
    print("%d:%d: vs=%s" % (message.partition, message.offset, message.value))
