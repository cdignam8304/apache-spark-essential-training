# %%
#Consumer test
from kafka import KafkaConsumer
import redis
import time
import mariadb

def string_deserializer(value):
    return value.decode('utf-8')

#Setup Kafka
visits_topic="spark.streaming.carts.abandoned"
    
visits_consumer=KafkaConsumer(
                bootstrap_servers=["localhost:9092"],
                group_id=None,
                value_deserializer=string_deserializer,
                auto_offset_reset="latest"
                )

visits_consumer.subscribe(visits_topic)

#Setup redis
redis_conn=redis.Redis(host="localhost", port=6379, decode_responses=True)

#setup mariadb conn
summary_conn = mariadb.connect(
                user="spark",
                password="spark",
                host="127.0.0.1",
                port=3306,
                database="website_stats",
                autocommit=True
            )
summary_cursor = summary_conn.cursor()
    
summary_stats_sql=f"""
            SELECT last_action, SUM(duration) as duration
            FROM `website_stats`.`visit_stats` 
            GROUP BY last_action
            """

while(True):

    print("\n**************************************************")
    #Fetch Kafka messages
    messages = visits_consumer.poll()
    print("Shopping Cart from Kafka\n-------------------------")
    for partition,records in messages.items():
        for record in records:
            print(record.value)

    #Print country stats from Redis
    print("\nCountry Stats from Redis\n-------------------------")
    scores=redis_conn.zrevrangebyscore("last-action-stats",99999,0,withscores=True)
    for score in scores:
        print(score[0], " = ", score[1])

    #Print summary stats for last action
    print("\nLast Action stats from mariaDB\n----------------------")
    summary_cursor.execute(summary_stats_sql)
    for last_action, duration in summary_cursor:
        print(last_action, " = ", duration)

    time.sleep(5)
# Out:
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# India  =  19.0
# USA  =  17.0
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# India  =  34.0
# USA  =  17.0
# Russia  =  5.0
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# USA,ShoppingCart,1743163516000000,17
#
# Country Stats from Redis
# -------------------------
# USA  =  37.0
# India  =  34.0
# Russia  =  6.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  19
# ShoppingCart  =  17
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  56.0
# India  =  43.0
# Russia  =  19.0
# Australia  =  16.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  19
# FAQ  =  5
# Order  =  15
# ShoppingCart  =  17
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# USA,ShoppingCart,1743163531000000,19
# Australia,ShoppingCart,1743163534000000,16
#
# Country Stats from Redis
# -------------------------
# USA  =  56.0
# India  =  43.0
# Australia  =  20.0
# Russia  =  19.0
# Brazil  =  2.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  20
# FAQ  =  5
# Order  =  35
# ShoppingCart  =  17
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  68.0
# India  =  43.0
# Australia  =  29.0
# Russia  =  19.0
# Brazil  =  2.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  20
# FAQ  =  18
# Order  =  44
# ShoppingCart  =  52
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  88.0
# India  =  43.0
# Australia  =  41.0
# Russia  =  19.0
# Brazil  =  3.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  20
# FAQ  =  18
# Order  =  50
# ShoppingCart  =  52
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  88.0
# Australia  =  56.0
# India  =  43.0
# Russia  =  29.0
# Brazil  =  3.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  34
# FAQ  =  18
# Order  =  57
# ShoppingCart  =  52
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Russia,ShoppingCart,1743163553000000,10
#
# Country Stats from Redis
# -------------------------
# USA  =  106.0
# Australia  =  56.0
# India  =  43.0
# Russia  =  29.0
# Brazil  =  23.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  67
# FAQ  =  18
# Order  =  57
# ShoppingCart  =  52
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  113.0
# India  =  63.0
# Australia  =  58.0
# Russia  =  29.0
# Brazil  =  23.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  67
# FAQ  =  18
# Order  =  72
# ShoppingCart  =  62
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  117.0
# India  =  63.0
# Australia  =  61.0
# Russia  =  29.0
# Brazil  =  23.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  67
# FAQ  =  18
# Order  =  110
# ShoppingCart  =  62
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  131.0
# Australia  =  79.0
# India  =  63.0
# Russia  =  29.0
# Brazil  =  23.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  94
# FAQ  =  18
# Order  =  112
# ShoppingCart  =  62
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# USA,ShoppingCart,1743163569000000,4
#
# Country Stats from Redis
# -------------------------
# USA  =  133.0
# Australia  =  83.0
# India  =  63.0
# Russia  =  45.0
# Brazil  =  23.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  94
# FAQ  =  21
# Order  =  112
# ShoppingCart  =  66
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  133.0
# Australia  =  86.0
# India  =  63.0
# Russia  =  49.0
# Brazil  =  39.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  108
# FAQ  =  21
# Order  =  130
# ShoppingCart  =  66
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Australia,ShoppingCart,1743163575000000,4
# Australia,ShoppingCart,1743163580000000,3
#
# Country Stats from Redis
# -------------------------
# USA  =  133.0
# Australia  =  98.0
# India  =  63.0
# Russia  =  49.0
# Brazil  =  47.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  108
# FAQ  =  23
# Order  =  146
# ShoppingCart  =  70
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  146.0
# Australia  =  117.0
# India  =  63.0
# Russia  =  49.0
# Brazil  =  47.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  112
# FAQ  =  23
# Order  =  162
# ShoppingCart  =  73
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Brazil,ShoppingCart,1743163586000000,8
# Australia,ShoppingCart,1743163588000000,12
#
# Country Stats from Redis
# -------------------------
# USA  =  152.0
# Australia  =  117.0
# India  =  63.0
# Russia  =  50.0
# Brazil  =  47.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  112
# FAQ  =  23
# Order  =  162
# ShoppingCart  =  93
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# USA  =  163.0
# Australia  =  129.0
# India  =  66.0
# Russia  =  50.0
# Brazil  =  47.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  131
# FAQ  =  23
# Order  =  175
# ShoppingCart  =  93
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# USA,ShoppingCart,1743163598000000,6
#
# Country Stats from Redis
# -------------------------
# USA  =  182.0
# Australia  =  129.0
# India  =  66.0
# Russia  =  50.0
# Brazil  =  48.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  131
# FAQ  =  23
# Order  =  176
# ShoppingCart  =  99
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      61 for last_action, duration in summary_cursor:
#      62     print(last_action, " = ", duration)
# ---> 64 time.sleep(5)
#
# KeyboardInterrupt:
